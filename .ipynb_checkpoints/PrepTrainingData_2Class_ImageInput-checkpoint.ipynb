# %% [markdown]
# # Organize directories

# %% [markdown]
# The first step in training a ML model on sequences of images acquired from the ProtectCode app is to ensure the directory structure is set up for subsequent data loading.
#
# These commands assume the following:
#
# 1) That the top directory for the training data and this notebook are both located in ~/src/YPB-AI/ on the EC2 instance. To get a zipped directory from S3 to that directory on your EC2 instance, you can run the following bash command: "aws s3 cp s3://your-bucket-name/yourZipFile.zip ~/src/YPB-AI/yourZipFile.zip". And to unzip it, you can run "unzip yourZipFile.zip"
#
# 2) That the jupyter notebook server was opened from the ~/src/ directory on the EC2 instance via the command "jupyter notebook --ip=0.0.0.0 --no-browser".
#
# 3) That underneath the top directory (which I usually call "Training" or something of the like), there are a series of subdirectories named and organized by classification label. For instance, each subdirectory that contains true negative image sequences, according to my implementation, contains the word "Negative". And subdirectories with true positives do not contain the word "Negative".

# %%
import numpy as np
from glob import glob
import os, sys
import re

# %% [markdown]
# Set the name of your top data directory below.

# %%
# topDirName = 'Training'
topDirName = 'Training2'

# %% [markdown]
# Lump together all subdirectories with the same classification label.

# %%
#Assumes current working directory is ~/src/YPB-AI
allSamples = np.array(glob(topDirName + '/*'))
os.system('mkdir ' + topDirName + '/Absent')
os.system('mkdir ' + topDirName + '/Present')

for sample in allSamples: 
    if 'Negative' in sample or 'Sat' in sample:
        cmdString = "mv " + sample + " " + topDirName + "/Absent"
    else:
        cmdString = "mv " + sample + " " + topDirName + "/Present"
    os.system(cmdString)

# %% [markdown]
# Each directory within the classification subdirectory contains a series of folders that have the following contents:
#
# 1) A .txt file containing some timing and other metadata about the app run.
#
# 2) A folder called 'Photos' which contains the sequence of images acquired.
#
# The next cell will obliterate the middle directory (the directory just below the classification directory) and repackage each run's photos into a uniquely identifiable folder of its own (lacking the text file) at the level where the middle directories once sat.

# %%
# Find 'vestigial' directories to be deleted after unpacking.
presentVestDirs = np.array(glob(topDirName + '/Present/*'))
absentVestDirs = np.array(glob(topDirName + '/Absent/*'))

# Unpack the JPG photo files into identifiable directories.
allPresentSamples = np.array(glob(topDirName + '/Present/*/*'))
for sample in allPresentSamples:
    # Grab the unique identifiers -- phone model, sample # and date/time
    digestedSample = re.split('/',sample)
    digestedTimestamp = re.split('_',digestedSample[3])
    newDir = digestedSample[2] + '_' + digestedTimestamp[1] + '_' + digestedTimestamp[2]
    # Make the new directory
    cmdString = 'mkdir ' + topDirName + '/Present/' + newDir
    os.system(cmdString)
    # Add the photos directly to it
    cmdString = 'mv ' + sample + '/Photos/*' + ' ' + topDirName + '/Present/' + newDir
    os.system(cmdString)
    
allAbsentSamples = np.array(glob(topDirName + '/Absent/*/*'))
for sample in allAbsentSamples:
    # Grab the unique identifiers -- phone model, sample # and date/time
    digestedSample = re.split('/',sample)
    digestedTimestamp = re.split('_',digestedSample[3])
    newDir = digestedSample[2] + '_' + digestedTimestamp[1] + '_' + digestedTimestamp[2]
    # Make the new directory
    cmdString = 'mkdir ' + topDirName + '/Absent/' + newDir
    os.system(cmdString)
    # Add the photos directly to it
    cmdString = 'mv ' + sample + '/Photos/*' + ' ' + topDirName + '/Absent/' + newDir
    os.system(cmdString)
    
    
# Delete vestigial directories.
for direc in presentVestDirs:
    os.system('rm -rf ' + direc)
    
for direc in absentVestDirs:
    os.system('rm -rf ' + direc)

# %% [markdown]
# Look through all directories and find image sequences containing the file "IMG_9999.JPG". If found, sort and rename to an appropriate image sequence. This is necessary because when iOS reaches "IMG_9999.JPG" it wraps back around to "IMG_0000.JPG" for the next in the sequence. If this is left as is, the sorting operation that follows will sort the images into the incorrect timing order.

# %%
# Get the filenames.
imgSeqsToCorrect = os.popen('cd ~/src/YPB-AI/; find -name "*IMG_9999.JPG"').read()
# Split into unique entities.
imgSeqsToCorrect = re.split('\n',imgSeqsToCorrect)
# Drop the last entry, it's empty.
imgSeqsToCorrect.pop();

# Change any files that don't start with 'IMG_9' (i.e., any files that come after the wraparound) to start with 'J'.
# This will mean that when they are sorted, they will come correctly after the wraparound.
for sample in imgSeqsToCorrect:
    digestedSample = re.split('/',sample)
    pathToDir = os.path.join(digestedSample[0],digestedSample[1],digestedSample[2],digestedSample[3])
    filesInDir = os.listdir(pathToDir)
    for i in range(len(filesInDir)):
        if 'IMG_9' not in filesInDir[i]:
            newFile = filesInDir[i].replace('I','J',1)
            cmdString = 'mv ' + os.path.join(pathToDir,filesInDir[i]) + ' ' + os.path.join(pathToDir,newFile)
            os.system(cmdString)

# %% [markdown]
# # Change the images in the folder into a stack of 12-image input

# %%
import torch
import torchvision.models as models
from PIL import Image
import pickle

# %%
topdir = topDirName
ndx = 0
topdirs = [direc for direc in os.listdir(topdir) if direc[0] is not '.']

# Calculate the total number of stacks to transform.
numStacks = 0
for classDir in topdirs:
    thisClassDir = os.path.join(topdir,classDir)
    directories = [direc for direc in os.listdir(thisClassDir) if direc[0] is not '.']
    numStacks += len(directories)

for classDir in topdirs:
    thisClassDir = os.path.join(topdir,classDir)
    directories = [direc for direc in os.listdir(thisClassDir) if direc[0] is not '.']


    # Do the transformation.
    for photoDir in directories:

        thisPhotoDir = os.path.join(thisClassDir, photoDir)
        ##pin pin fix##

#             print(thisPhotoDir)
#             print(os.path.isfile(photoDir))
#             continue

        if not os.path.isdir(thisPhotoDir):
            continue

        ## end ##
        files = [photofile for photofile in os.listdir(thisPhotoDir) if photofile.lower().endswith('jpg')]
        print("Transforming image stack {}".format(thisPhotoDir))
        files.sort()
        output = []
        # Make sure to appropriately transform the image size and normalize the RGB values, as the model expects. 
        for file in files:
            thisFile = os.path.join(thisPhotoDir,file)
            imgArr = np.float32(np.array(Image.open(thisFile).resize((32,32))).reshape([1,3,32,32]))
            imgArr[0][0] = ((imgArr[0][0] - 123.675)/58.395)
            imgArr[0][1] = ((imgArr[0][1] - 116.28)/57.12)
            imgArr[0][2] = ((imgArr[0][2] - 103.53)/57.375)
            output.append(imgArr)

        FinalOutput = torch.FloatTensor(output)
        # for i in range(len(files)):
        #    FinalOutput[i] = output[i]
        pathStr = thisPhotoDir + '.pickle'
        with open(pathStr,'wb') as f:
            pickle.dump(FinalOutput,f)
            ndx += 1
            print("{}% complete.".format(ndx/numStacks*100))
# Out:
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-59-47
# 0.008768084173608068% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-13-37
# 0.017536168347216136% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-17-37
# 0.026304252520824196% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-37-50
# 0.03507233669443227% complete.
# Transforming image stack Training2/Absent/XS_Sat_17-Apr-2019_11-36-09
# 0.04384042086804033% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-11-36
# 0.05260850504164839% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-01-20
# 0.06137658921525647% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_16-46-00
# 0.07014467338886454% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-21-25
# 0.0789127575624726% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-56-35
# 0.08768084173608066% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-47-38
# 0.09644892590968873% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-10-40
# 0.10521701008329679% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-57-41
# 0.11398509425690487% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-04-00
# 0.12275317843051294% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-39-26
# 0.131521262604121% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-59-01
# 0.14028934677772908% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_10-31-20
# 0.1490574309513371% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-37-27
# 0.1578255151249452% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-51-55
# 0.16659359929855327% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-49-24
# 0.17536168347216133% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-12-55
# 0.1841297676457694% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-52-58
# 0.19289785181937746% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-27-13
# 0.20166593599298555% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-55-43
# 0.21043402016659357% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_18-08-14
# 0.21920210434020165% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-44-45
# 0.22797018851380974% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-38-20
# 0.2367382726874178% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-32-42
# 0.24550635686102587% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-52-14
# 0.2542744410346339% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-42-38
# 0.263042525208242% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-54-52
# 0.2718106093818501% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-14-25
# 0.28057869355545817% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-14-40
# 0.2893467777290662% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-57-00
# 0.2981148619026742% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-31-36
# 0.3068829460762823% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-35-32
# 0.3156510302498904% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-02-51
# 0.32441911442349847% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_15-25-20
# 0.33318719859710655% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-29-10
# 0.34195528277071463% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-27-43
# 0.35072336694432266% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-04-50
# 0.35949145111793074% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_15-40-05
# 0.3682595352915388% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-34-06
# 0.37702761946514685% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-28-15
# 0.3857957036387549% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-31-49
# 0.394563787812363% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-41-48
# 0.4033318719859711% complete.
# Transforming image stack Training2/Absent/6S_Sat_03-Jun-2019_15-27-04
# 0.41209995615957906% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019
complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_15-32-21
# 0.7803594914511179% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-52-23
# 0.789127575624726% complete.
# Transforming image stack Training2/Absent/XS_Sat_30-May-2019_15-38-35
# 0.7978956597983341% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_19-16-10
# 0.8066637439719422% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-29-12
# 0.8154318281455502% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-27-05
# 0.8241999123191581% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-44-01
# 0.8329679964927663% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-00-29
# 0.8417360806663743% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-57-37
# 0.8505041648399825% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-22-31
# 0.8592722490135905% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-41-49
# 0.8680403331871986% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_14-41-51
# 0.8768084173608066% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-34-11
# 0.8855765015344148% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_18-11-57
# 0.8943445857080228% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-34-56
# 0.9031126698816309% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-50-04
# 0.9118807540552389% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-18-07
# 0.920648838228847% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-09-21
# 0.929416922402455% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-25-35
# 0.9381850065760632% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-49-22
# 0.9469530907496712% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-26-29
# 0.9557211749232793% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-19-54
# 0.9644892590968873% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-45-22
# 0.9732573432704955% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_10-30-46
# 0.9820254274441035% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-19-12
# 0.9907935116177115% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-04-35
# 0.9995615957913196% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-05-31
# 1.0083296799649275% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-37-57
# 1.0170977641385357% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-08-32
# 1.0258658483121437% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-04-14
# 1.0346339324857519% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-27-54
# 1.0434020166593598% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-45-39
# 1.052170100832968% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_14-14-54
# 1.060938185006576% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-46-30
# 1.0697062691801842% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-13-06
# 1.0784743533537922% complete.
# Transforming image stack Training2/Absent/6S_Sat_03-Jun-2019_15-11-25
# 1.0872424375274004% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-06-09
# 1.0960105217010083% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-34-32
# 1.1047786058746165% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-34-08
# 1.1135466900482245% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-20-53
# 1.1223147742218327% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random
complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-11-02
# 1.5168785620341956% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_15-53-12
# 1.5256466462078035% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-20-24
# 1.5344147303814117% complete.
# Transforming image stack Training2/Absent/XS_Sat_17-Apr-2019_12-07-18
# 1.5431828145550197% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-35-56
# 1.551950898728628% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_10-29-40
# 1.5607189829022359% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_15-49-46
# 1.5694870670758438% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-13-46
# 1.578255151249452% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-30-59
# 1.58702323542306% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-50-50
# 1.5957913195966682% complete.
# Transforming image stack Training2/Absent/XS_Sat_17-Apr-2019_11-21-34
# 1.6045594037702762% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-36-53
# 1.6133274879438844% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-36-16
# 1.6220955721174923% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-24-52
# 1.6308636562911003% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-53-10
# 1.6396317404647083% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-37-51
# 1.6483998246383162% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-08-25
# 1.6571679088119247% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-59-50
# 1.6659359929855326% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-48-54
# 1.6747040771591406% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-45-29
# 1.6834721613327486% complete.
# Transforming image stack Training2/Absent/6_Sat_03-Jun-2019_16-09-05
# 1.692240245506357% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-37-08
# 1.701008329679965% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-21-07
# 1.709776413853573% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-30-18
# 1.718544498027181% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-36-46
# 1.7273125822007893% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-03-52
# 1.7360806663743973% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-19-40
# 1.7448487505480053% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-10-38
# 1.7536168347216132% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-04-46
# 1.7623849188952216% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-27-28
# 1.7711530030688296% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-36-53
# 1.7799210872424376% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-35-57
# 1.7886891714160456% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-48-01
# 1.7974572555896537% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-54-36
# 1.8062253397632617% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-20-16
# 1.81499342393687% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-59-02
# 1.8237615081104779% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-11-44
# 1.8325295922840859% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_13-49-07
# 1.841297676457694% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019
complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-36-05
# 2.612889083735204% complete.
# Transforming image stack Training2/Absent/XS_Sat_03-Jun-2019_16-41-19
# 2.621657167908812% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-55-13
# 2.63042525208242% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-14-52
# 2.639193336256028% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-56-13
# 2.647961420429636% complete.
# Transforming image stack Training2/Absent/6_Sat_16-Apr-2019_13-29-26
# 2.6567295046032444% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-14-21
# 2.6654975887768524% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-50-05
# 2.6742656729504604% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-25-40
# 2.6830337571240683% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_15-39-59
# 2.6918018412976767% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-22-38
# 2.7005699254712847% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-23-35
# 2.7093380096448927% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-07-57
# 2.7181060938185007% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-09-04
# 2.726874177992109% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-27-46
# 2.735642262165717% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-23-01
# 2.744410346339325% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-01-54
# 2.753178430512933% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-37-51
# 2.761946514686541% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-24-40
# 2.770714598860149% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-53-43
# 2.7794826830337573% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-33-01
# 2.7882507672073653% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-24-39
# 2.7970188513809733% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-52-49
# 2.8057869355545813% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-17-27
# 2.8145550197281892% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-35-44
# 2.823323103901797% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-51-47
# 2.832091188075405% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-39-51
# 2.8408592722490136% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-52-49
# 2.8496273564226215% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-02-24
# 2.8583954405962295% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-24-18
# 2.8671635247698375% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-18-22
# 2.875931608943446% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_14-42-51
# 2.884699693117054% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-43-24
# 2.893467777290662% complete.
# Transforming image stack Training2/Absent/XS_Sat_17-Apr-2019_12-04-06
# 2.90223586146427% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-10-42
# 2.9110039456378782% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-32-22
# 2.919772029811486% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_14-29-54
# 2.928540113985094% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-22-53
# 2.937308198158702% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-06-07
# 2.9460762823323106% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-20-30
# 2.9548443665059185% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_17-01-25
# 2.9636124506795265% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-16-35
# 2.9723805348531345% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-15-48
# 2.9811486190267424% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-38-01
# 2.989916703200351% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-33-13
# 2.998684787373959% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-26-45
# 3.007452871547567% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-42-14
# 3.0162209557211748% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-25-08
# 3.024989039894783% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-20-16
# 3.033757124068391% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-56-09
# 3.042525208241999% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-31-23
# 3.051293292415607% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-55-26
# 3.0600613765892155% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-06-42
# 3.0688294607628235% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-29-16
# 3.0775975449364315% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_16-56-27
# 3.0863656291100394% complete.
# Transforming image stack Training2/Absent/XS_Sat_30-May-2019_15-50-54
# 3.095133713283648% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-02-33
# 3.103901797457256% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-16-40
# 3.1126698816308638% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-52-08
# 3.1214379658044717% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-50-51
# 3.13020604997808% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-31-35
# 3.1389741341516877% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-20-37
# 3.147742218325296% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-40-56
# 3.156510302498904% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-41-15
# 3.165278386672512% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-38-29
# 3.17404647084612% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-01-29
# 3.182814555019728% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_15-56-25
# 3.1915826391933364% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-52-01
# 3.2003507233669444% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-35-21
# 3.2091188075405523% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-19-57
# 3.2178868917141603% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-25-27
# 3.2266549758877687% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_10-07-10
# 3.2354230600613763% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-41-37
# 3.2441911442349847% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-25-20
# 3.2529592284085926% complete.
# Transforming image stack Training2/Absent/6_Sat_16-Apr-2019_14-41-35
# 3.2617273125822006% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-32-32
# 3.270495396755809% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_18-06-42
# 3.2792634809294166% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-37-25
# 3.288031565103025% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-14-37
# 3.2967996492766325% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_17-29-36
# 3.305567733450241% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-15-57
# 3.3143358176238493% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-09-52
# 3.323103901797457% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_13-51-44
# 3.3318719859710653% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-57-24
# 3.3406400701446737% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-43-22
# 3.349408154318281% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_17-00-43
# 3.3581762384918896% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-29-27
# 3.366944322665497% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-21-41
# 3.3757124068391056% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-49-33
# 3.384480491012714% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-34-10
# 3.3932485751863215% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_12-52-04
# 3.40201665935993% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-21-05
# 3.4107847435335383% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-55-10
# 3.419552827707146% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-07-33
# 3.4283209118807543% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-43-19
# 3.437088996054362% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-53-53
# 3.44585708022797% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-44-05
# 3.4546251644015786% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_11-46-41
# 3.463393248575186% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_18-10-05
# 3.4721613327487946% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-13-03
# 3.480929416922402% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_04-Jun-2019_10-20-33
# 3.4896975010960105% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-06-21
# 3.498465585269619% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_11-54-04
# 3.5072336694432265% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_17-38-17
# 3.516001753616835% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-39-27
# 3.5247698377904433% complete.
# Transforming image stack Training2/Absent/XS_Negative_Random_30-May-2019_16-00-13
# 3.533537921964051% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-17-17
# 3.5423060061376592% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_14-48-40
# 3.5510740903112668% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-30-45
# 3.559842174484875% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-01-32
# 3.5686102586584836% complete.
# Transforming image stack Training2/Absent/6S_Negative_Dark_14-Mar-2019_09-35-37
# 3.577378342832091% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_15-00-04
# 3.5861464270056995% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-40-17
# 3.5949145111793075% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-53-06
# 3.6036825953529155% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-29-38
# 3.6124506795265234% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-32-54
# 3.6212187637001314% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-53-46
# 3.62998684787374% complete.
# Transforming image stack Training2/Absent/SE_Negative_Dark_15-Mar-2019_16-28-25
# 3.638754932047348% complete.
# Transforming image stack Training2/Absent/XS_Sat_07-Jun-2019_13-48-37
# 3.6475230162209558% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-21-20
# 3.6562911003945637% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-31-27
# 3.6650591845681717% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_19-57-00
# 3.6738272687417797% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_18-09-32
# 3.682595352915388% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-42-36
# 3.691363437088996% complete.
# Transforming image stack Training2/Absent/6S_Negative_Random_03-Jun-2019_14-55-08
# 3.700131521262604% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_17-16-26
# 3.7088996054362124% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-22-04
# 3.71766768960982% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_10-44-40
# 3.7264357737834284% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_14-13-37
# 3.735203857957036% complete.
# Transforming image stack Training2/Absent/6_Negative_Dark_13-Mar-2019_13-13-29
# 3.7439719421306443% complete.
# Transforming image stack Training2/Absent/7_Negative_Random_30-May-2019_17-24-42
# 3.7527400263042527% complete.
# Transforming image stack Training2/Absent/6S_Sat_16-Apr-2019_15-35-00
# 3.7615081104778603% complete.
# Transforming image stack Training2/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-35-47
# 3.7702761946514687% complete.
# Transforming image stack Training2/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-05-09
# 3.779044278825076% complete.
# Transforming image stack Training2/Absent/7_Negative_Dark_13-Mar-2019_16-05-02
# 3.7878123629986846% complete.
# Transforming image stack Training2/Absent/XS_Negative_Dark_14-Mar-2019_18-41-17
# 3.796580447172293% complete.
# Transforming image stack Training2/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-16-19
# 3.8053485313459006% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-47-01
# 3.814116615519509% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_20-16-04
# 3.8228846996931174% complete.
# Transforming image stack Training2/Absent/SE_Negative_Random_03-Jun-2019_16-56-44
# 3.831652783866725% complete.
# Transforming image stack Training2/Absent/XS_Sat2_07-Jun-2019_18-30-10
# 3.8404208680403333% complete.
# Transforming image stack Training2/Absent/7_Sat_30-May-2019_16-57-46
# 3.849188952213941% complete.
# Transforming image stack Training2/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-02-50
# 3.8579570363875493% complete.
# ...
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_18-06-13
# 87.33011836913634% complete.
# Transforming image stack Training2/Present/SE_Sample3_Dark_11-Mar-2019_12-10-21
# 87.33888645330995% complete.
# Transforming image stack Training2/Present/6S_Sample4_Dark_08-Mar-2019_13-09-39
# 87.34765453748355% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_11-29-47
# 87.35642262165717% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_17-09-28
# 87.36519070583077% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_11-39-55
# 87.37395879000438% complete.
# Transforming image stack Training2/Present/7_Sample3_Dark_12-Mar-2019_13-10-12
# 87.38272687417799% complete.
# Transforming image stack Training2/Present/7_Sample4_Dark_12-Mar-2019_12-18-54
# 87.3914949583516% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-29-59
# 87.40026304252521% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-37-02
# 87.40903112669882% complete.
# Transforming image stack Training2/Present/XS_Sample1_Dark_12-Mar-2019_15-32-12
# 87.41779921087243% complete.
# Transforming image stack Training2/Present/7_Sample1_Dark_12-Mar-2019_14-30-53
# 87.42656729504603% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_17-04-18
# 87.43533537921964% complete.
# Transforming image stack Training2/Present/6_Sample4_Dark_08-Mar-2019_15-05-25
# 87.44410346339325% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_11-10-55
# 87.45287154756686% complete.
# Transforming image stack Training2/Present/XS_Sample2_Dark_12-Mar-2019_16-15-58
# 87.46163963174047% complete.
# Transforming image stack Training2/Present/SE_Sample2_Dark_11-Mar-2019_11-17-15
# 87.47040771591408% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-12-59
# 87.47917580008769% complete.
# Transforming image stack Training2/Present/7_Sample3_Light_27-Mar-2019_14-45-36
# 87.48794388426128% complete.
# Transforming image stack Training2/Present/6_Sample2_Dark_08-Mar-2019_17-30-55
# 87.4967119684349% complete.
# Transforming image stack Training2/Present/6_Sample1_Dark_12-Mar-2019_18-17-04
# 87.5054800526085% complete.
# Transforming image stack Training2/Present/XS_Sample2_Dark_12-Mar-2019_15-58-09
# 87.51424813678211% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_15-40-34
# 87.52301622095572% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_13-37-42
# 87.53178430512934% complete.
# Transforming image stack Training2/Present/7_Sample5_Dark_12-Mar-2019_11-36-52
# 87.54055238930295% complete.
# Transforming image stack Training2/Present/7_Sample3_Light_27-Mar-2019_15-11-19
# 87.54932047347654% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_15-24-49
# 87.55808855765015% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_12-22-18
# 87.56685664182376% complete.
# Transforming image stack Training2/Present/6S_Sample5_Dark_08-Mar-2019_13-41-55
# 87.57562472599737% complete.
# Transforming image stack Training2/Present/6_Sample3_Light_25-Mar-2019_16-26-16
# 87.58439281017097% complete.
# Transforming image stack Training2/Present/6_Sample3_Light_25-Mar-2019_16-00-41
# 87.59316089434459% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-14-30
# 87.6019289785182% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_18-00-47
# 87.6106970626918% complete.
# Transforming image stack Training2/Present/6S_Sample1_Dark_08-Mar-2019_12-03-20
# 87.61946514686541% complete.
# Transforming image stack Training2/Present/6S_Sample2_Dark_08-Mar-2019_10-49-26
# 87.62823323103902% complete.
# Transforming image stack Training2/Present/SE_Sample5_Light_01-Apr-2019_16-10-24
# 87.63700131521263% complete.
# Transforming image stack Training2/Present/7_Sample5_Dark_12-Mar-2019_11-52-37
# 87.64576939938623% complete.
# Transforming image stack Training2/Present/6_Sample3_Dark_08-Mar-2019_16-01-25
# 87.65453748355985% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-00-48
# 87.66330556773345% complete.
# Transforming image stack Training2/Present/6_Sample2_Dark_08-Mar-2019_16-56-40
# 87.67207365190706% complete.
# Transforming image stack Training2/Present/6_Sample3_Dark_08-Mar-2019_16-00-40
# 87.68084173608067% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_12-49-40
# 87.68960982025428% complete.
# Transforming image stack Training2/Present/6_Sample4_Dark_08-Mar-2019_15-25-12
# 87.69837790442789% complete.
# Transforming image stack Training2/Present/XS_Sample5_Light_27-Mar-2019_17-33-55
# 87.70714598860148% complete.
# Transforming image stack Training2/Present/XS_Sample5_Light_27-Mar-2019_16-52-44
# 87.7159140727751% complete.
# Transforming image stack Training2/Present/6_Sample1_Dark_12-Mar-2019_18-14-42
# 87.7246821569487% complete.
# Transforming image stack Training2/Present/SE_Sample1_Dark_07-Mar-2019_16-23-26
# 87.73345024112231% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_14-01-19
# 87.74221832529592% complete.
# Transforming image stack Training2/Present/6_Sample1_Dark_12-Mar-2019_18-12-16
# 87.75098640946953% complete.
# Transforming image stack Training2/Present/6S_Sample2_Dark_08-Mar-2019_11-18-33
# 87.75975449364314% complete.
# Transforming image stack Training2/Present/XS_Sample5_Light_27-Mar-2019_16-49-38
# 87.76852257781674% complete.
# Transforming image stack Training2/Present/7_Sample3_Light_27-Mar-2019_15-11-03
# 87.77729066199036% complete.
# Transforming image stack Training2/Present/6_Sample4_Dark_08-Mar-2019_15-11-14
# 87.78605874616396% complete.
# Transforming image stack Training2/Present/7_Sample5_Dark_12-Mar-2019_11-51-25
# 87.79482683033757% complete.
# Transforming image stack Training2/Present/7_Sample3_Dark_12-Mar-2019_12-58-48
# 87.80359491451118% complete.
# Transforming image stack Training2/Present/XS_Sample5_Dark_12-Mar-2019_17-35-34
# 87.81236299868479% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_15-34-48
# 87.8211310828584% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_12-29-24
# 87.829899167032% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_14-57-44
# 87.83866725120562% complete.
# Transforming image stack Training2/Present/6S_Sample4_Dark_08-Mar-2019_13-11-20
# 87.84743533537922% complete.
# Transforming image stack Training2/Present/6_Sample3_Light_25-Mar-2019_14-59-41
# 87.85620341955283% complete.
# Transforming image stack Training2/Present/6S_Distance_and_Curved_13-Jun-2019_16-42-26
# 87.86497150372644% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_13-31-57
# 87.87373958790005% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_14-Jun-2019_10-50-51
# 87.88250767207366% complete.
# Transforming image stack Training2/Present/XS_Sample5_Light_27-Mar-2019_17-26-01
# 87.89127575624725% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-20-31
# 87.90004384042088% complete.
# Transforming image stack Training2/Present/6S_Sample4_Dark_08-Mar-2019_13-02-51
# 87.90881192459447% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_15-38-32
# 87.91758000876808% complete.
# Transforming image stack Training2/Present/6_Distance_and_Curved_13-Jun-2019_16-07-55
# 87.9263480929417% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_15-22-20
# 87.9351161771153% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_17-18-05
# 87.9438842612889% complete.
# Transforming image stack Training2/Present/XS_Sample2_Dark_12-Mar-2019_16-08-01
# 87.95265234546251% complete.
# Transforming image stack Training2/Present/6_Sample4_Dark_08-Mar-2019_15-33-42
# 87.96142042963612% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_15-02-07
# 87.97018851380973% complete.
# Transforming image stack Training2/Present/6S_Sample1_Dark_08-Mar-2019_11-41-07
# 87.97895659798334% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-19-24
# 87.98772468215695% complete.
# Transforming image stack Training2/Present/6S_Sample3_Light_27-Mar-2019_13-29-58
# 87.99649276633056% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_16-08-59
# 88.00526085050416% complete.
# Transforming image stack Training2/Present/7_Sample3_Light_27-Mar-2019_15-07-15
# 88.01402893467777% complete.
# Transforming image stack Training2/Present/6_Sample3_Dark_08-Mar-2019_16-19-58
# 88.02279701885138% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-26-16
# 88.03156510302499% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_16-34-10
# 88.0403331871986% complete.
# Transforming image stack Training2/Present/XS_Sample4_Dark_12-Mar-2019_17-07-30
# 88.04910127137221% complete.
# Transforming image stack Training2/Present/SE_Sample2_Dark_11-Mar-2019_10-50-28
# 88.05786935554582% complete.
# Transforming image stack Training2/Present/7_Sample4_Dark_12-Mar-2019_12-27-05
# 88.06663743971941% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-14-45
# 88.07540552389302% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_15-57-10
# 88.08417360806664% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_11-03-20
# 88.09294169224025% complete.
# Transforming image stack Training2/Present/6S_Sample4_Dark_08-Mar-2019_13-00-08
# 88.10170977641386% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-02-52
# 88.11047786058747% complete.
# Transforming image stack Training2/Present/7_Sample1_Dark_12-Mar-2019_14-23-38
# 88.11924594476108% complete.
# Transforming image stack Training2/Present/XS_Sample5_Light_27-Mar-2019_17-28-26
# 88.12801402893467% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_15-04-18
# 88.13678211310828% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_16-04-38
# 88.14555019728189% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_16-27-47
# 88.1543182814555% complete.
# Transforming image stack Training2/Present/SE_Sample1_Dark_07-Mar-2019_16-12-54
# 88.16308636562911% complete.
# Transforming image stack Training2/Present/7_Sample5_Dark_12-Mar-2019_12-03-20
# 88.17185444980272% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_11-02-14
# 88.18062253397633% complete.
# Transforming image stack Training2/Present/SE_Sample5_Dark_11-Mar-2019_14-45-37
# 88.18939061814993% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_16-07-17
# 88.19815870232354% complete.
# Transforming image stack Training2/Present/SE_Sample4_Dark_11-Mar-2019_12-33-15
# 88.20692678649715% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_17-06-08
# 88.21569487067076% complete.
# Transforming image stack Training2/Present/6S_Sample5_Dark_08-Mar-2019_13-52-59
# 88.22446295484437% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-32-25
# 88.23323103901798% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_16-45-21
# 88.24199912319159% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_16-46-12
# 88.25076720736519% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_14-Jun-2019_11-26-37
# 88.25953529153881% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_14-32-36
# 88.2683033757124% complete.
# Transforming image stack Training2/Present/SE_Sample5_Dark_11-Mar-2019_14-33-13
# 88.27707145988602% complete.
# Transforming image stack Training2/Present/SE_Sample5_Dark_11-Mar-2019_14-36-24
# 88.28583954405961% complete.
# Transforming image stack Training2/Present/7_Sample4_Dark_12-Mar-2019_12-40-23
# 88.29460762823324% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_15-21-24
# 88.30337571240683% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-12-51
# 88.31214379658044% complete.
# Transforming image stack Training2/Present/7_Sample2_Dark_12-Mar-2019_13-30-16
# 88.32091188075407% complete.
# Transforming image stack Training2/Present/SE_Sample5_Light_01-Apr-2019_15-59-02
# 88.32967996492766% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_14-14-39
# 88.33844804910127% complete.
# Transforming image stack Training2/Present/6S_Sample5_Dark_08-Mar-2019_13-44-38
# 88.34721613327487% complete.
# Transforming image stack Training2/Present/7_Sample5_Light_27-Mar-2019_16-22-00
# 88.3559842174485% complete.
# Transforming image stack Training2/Present/7_Sample4_Dark_12-Mar-2019_12-46-24
# 88.36475230162209% complete.
# Transforming image stack Training2/Present/SE_Sample2_Dark_11-Mar-2019_11-05-02
# 88.3735203857957% complete.
# Transforming image stack Training2/Present/6S_Distance_and_Curved_13-Jun-2019_16-52-26
# 88.38228846996931% complete.
# Transforming image stack Training2/Present/7_Sample3_Dark_12-Mar-2019_13-10-28
# 88.39105655414292% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-26-33
# 88.39982463831653% complete.
# Transforming image stack Training2/Present/XS_Sample1_Dark_12-Mar-2019_15-17-34
# 88.40859272249013% complete.
# Transforming image stack Training2/Present/7_Sample2_Dark_12-Mar-2019_13-36-48
# 88.41736080666375% complete.
# Transforming image stack Training2/Present/6S_Sample5_Dark_08-Mar-2019_13-36-00
# 88.42612889083735% complete.
# Transforming image stack Training2/Present/6S_Sample5_Dark_08-Mar-2019_13-26-49
# 88.43489697501096% complete.
# Transforming image stack Training2/Present/6S_Sample1_Dark_08-Mar-2019_11-42-51
# 88.44366505918457% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_15-08-20
# 88.45243314335818% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_15-02-22
# 88.46120122753179% complete.
# Transforming image stack Training2/Present/SE_Sample4_Dark_11-Mar-2019_12-36-51
# 88.46996931170538% complete.
# Transforming image stack Training2/Present/XS_Sample3_Dark_12-Mar-2019_16-43-44
# 88.47873739587901% complete.
# Transforming image stack Training2/Present/SE_Sample3_Light_28-Mar-2019_15-04-56
# 88.4875054800526% complete.
# Transforming image stack Training2/Present/7_Distance_and_Curved_13-Jun-2019_14-38-47
# 88.49627356422621% complete.
# Transforming image stack Training2/Present/7_Sample5_Dark_12-Mar-2019_11-39-51
# 88.50504164839982% complete.
# Transforming image stack Training2/Present/SE_Sample4_Dark_11-Mar-2019_12-47-41
# 88.51380973257343% complete.
# Transforming image stack Training2/Present/XS_Sample5_Dark_12-Mar-2019_17-26-55
# 88.52257781674705% complete.
# Transforming image stack Training2/Present/6S_Sample3_Dark_08-Mar-2019_12-20-46
# 88.53134590092064% complete.
# Transforming image stack Training2/Present/XS_Distance_and_Curved_13-Jun-2019_10-54-11
# 88.54011398509427% complete.
# Transforming image stack Training2/Present/SE_Sample5_Dark_11-Mar-2019_14-46-22
# 88.54888206926786% complete.
# Transforming image stack Training2/Present/XS_Sample3_Light_28-Mar-2019_13-37-29
# 88.55765015344147% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_16-11-57
# 88.56641823761508% complete.
# Transforming image stack Training2/Present/7_Sample3_Light_27-Mar-2019_14-30-56
# 88.57518632178869% complete.
# Transforming image stack Training2/Present/6S_Sample1_Dark_08-Mar-2019_11-50-34
# 88.58395440596229% complete.
# Transforming image stack Training2/Present/SE_Sample3_Dark_11-Mar-2019_12-15-30
# 88.5927224901359% complete.
# Transforming image stack Training2/Present/6_Sample5_Light_26-Mar-2019_17-47-55

# %% [markdown]
# Use a pretrained 11-layer VGG with the final classifier layer chopped off. >> no not using this

# %%
# Import the CNN model and move it to CUDA if available.
model = models.vgg(pretrained=True)

for param in model.parameters():
    param.requires_grad = False
del model.classifier

if torch.cuda.is_available():
    model.to('cuda');

# %% [markdown]
# Define the function that will transform model output into a pickle file.

# %%
def transform_to_pickle(model,topdir):
    model.eval()
    ndx = 0
    topdirs = [direc for direc in os.listdir(topdir) if direc[0] is not '.']
    
    # Calculate the total number of stacks to transform.
    numStacks = 0
    for classDir in topdirs:
        thisClassDir = os.path.join(topdir,classDir)
        directories = [direc for direc in os.listdir(thisClassDir) if direc[0] is not '.']
        numStacks += len(directories)
    
    for classDir in topdirs:
        thisClassDir = os.path.join(topdir,classDir)
        directories = [direc for direc in os.listdir(thisClassDir) if direc[0] is not '.']
        
        
        # Do the transformation.
        for photoDir in directories:
            
            thisPhotoDir = os.path.join(thisClassDir, photoDir)
            ##pin pin fix##
            
#             print(thisPhotoDir)
#             print(os.path.isfile(photoDir))
#             continue
            
            if not os.path.isdir(thisPhotoDir):
                continue

            ## end ##
            files = [photofile for photofile in os.listdir(thisPhotoDir) if photofile.lower().endswith('jpg')]
            print("Transforming image stack {}".format(thisPhotoDir))
            files.sort()
            output = []
            # Make sure to appropriately transform the image size and normalize the RGB values, as the model expects. 
            for file in files:
                thisFile = os.path.join(thisPhotoDir,file)
                imgArr = np.float32(np.array(Image.open(thisFile).resize((224,224))).reshape([1,3,224,224]))
                imgArr[0][0] = ((imgArr[0][0] - 123.675)/58.395)
                imgArr[0][1] = ((imgArr[0][1] - 116.28)/57.12)
                imgArr[0][2] = ((imgArr[0][2] - 103.53)/57.375)
                if torch.cuda.is_available():
                    output.append(model(torch.cuda.FloatTensor(imgArr)))
                else:
                    output.append(model(torch.FloatTensor(imgArr)))

            FinalOutput = imgArr
            pathStr = thisPhotoDir + '.pickle'
            with open(pathStr,'wb') as f:
                pickle.dump(FinalOutput,f)
                ndx += 1
                print("{}% complete.".format(ndx/numStacks*100))

# %% [markdown]
# Do the transformation

# %%
transform_to_pickle(model,topDirName)
# Out:
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-59-47
# 0.004384042086804034% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-13-37
# 0.008768084173608068% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-17-37
# 0.013152126260412098% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-37-50
# 0.017536168347216136% complete.
# Transforming image stack Training/Absent/XS_Sat_17-Apr-2019_11-36-09
# 0.021920210434020166% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-11-36
# 0.026304252520824196% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_13-01-20
# 0.030688294607628234% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_16-46-00
# 0.03507233669443227% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-21-25
# 0.0394563787812363% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-56-35
# 0.04384042086804033% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-47-38
# 0.048224462954844366% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-10-40
# 0.05260850504164839% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-57-41
# 0.056992547128452434% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-04-00
# 0.06137658921525647% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-39-26
# 0.0657606313020605% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-59-01
# 0.07014467338886454% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-31-20
# 0.07452871547566856% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-37-27
# 0.0789127575624726% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-51-55
# 0.08329679964927664% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-49-24
# 0.08768084173608066% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-12-55
# 0.0920648838228847% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-52-58
# 0.09644892590968873% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-27-13
# 0.10083296799649277% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-55-43
# 0.10521701008329679% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_18-08-14
# 0.10960105217010083% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-44-45
# 0.11398509425690487% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-38-20
# 0.1183691363437089% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-32-42
# 0.12275317843051294% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-52-14
# 0.12713722051731696% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-42-38
# 0.131521262604121% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-54-52
# 0.13590530469092504% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-14-25
# 0.14028934677772908% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-14-40
# 0.1446733888645331% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-57-00
# 0.1490574309513371% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-31-36
# 0.15344147303814115% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-35-32
# 0.1578255151249452% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-02-51
# 0.16220955721174923% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-25-20
# 0.16659359929855327% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-29-10
# 0.17097764138535732% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-27-43
# 0.17536168347216133% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-04-50
# 0.17974572555896537% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-40-05
# 0.1841297676457694% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-34-06
# 0.18851380973257342% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-28-15
# 0.19289785181937746% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-31-49
# 0.1972818939061815% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-41-48
# 0.20166593599298555% complete.
# Transforming image stack Training/Absent/6S_Sat_03-Jun-2019_15-27-04
# 0.20604997807978953% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-12-28
# 0.21043402016659357% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_09-59-51
# 0.2148180622533976% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-50-14
# 0.21920210434020165% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_16-44-20
# 0.2235861464270057% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-32-51
# 0.22797018851380974% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-07-03
# 0.23235423060061375% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-42-50
# 0.2367382726874178% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-28-05
# 0.24112231477422183% complete.
# Transforming image stack Training/Absent/XS_Sat_17-Apr-2019_11-36-24
# 0.24550635686102587% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-40-40
# 0.2498903989478299% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-51-57
# 0.2542744410346339% complete.
# Transforming image stack Training/Absent/6S_Sat_03-Jun-2019_14-19-25
# 0.25865848312143797% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-38-34
# 0.263042525208242% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-20-59
# 0.26742656729504605% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_14-32-57
# 0.2718106093818501% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-49-17
# 0.27619465146865413% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_15-43-48
# 0.28057869355545817% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-35-57
# 0.2849627356422622% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-27-08
# 0.2893467777290662% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-51-45
# 0.29373081981587024% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-01-40
# 0.2981148619026742% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-33-35
# 0.30249890398947826% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-36-47
# 0.3068829460762823% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-34-07
# 0.31126698816308634% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-27-49
# 0.3156510302498904% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-38-08
# 0.3200350723366944% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-34-25
# 0.32441911442349847% complete.
# Transforming image stack Training/Absent/XS_Sat_30-May-2019_14-41-10
# 0.3288031565103025% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-17-29
# 0.33318719859710655% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-38-24
# 0.3375712406839106% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-38-00
# 0.34195528277071463% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-05-52
# 0.3463393248575186% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-34-45
# 0.35072336694432266% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-46-34
# 0.3551074090311267% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-15-22
# 0.35949145111793074% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-42-51
# 0.3638754932047348% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-41-49
# 0.3682595352915388% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-23-41
# 0.3726435773783428% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-34-43
# 0.37702761946514685% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-15-47
# 0.3814116615519509% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-41-48
# 0.3857957036387549% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-32-21
# 0.39017974572555897% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-52-23
# 0.394563787812363% complete.
# Transforming image stack Training/Absent/XS_Sat_30-May-2019_15-38-35
# 0.39894782989916705% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_19-16-10
# 0.4033318719859711% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-29-12
# 0.4077159140727751% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-27-05
# 0.41209995615957906% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-44-01
# 0.41648399824638316% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-00-29
# 0.42086804033318714% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-57-37
# 0.42525208241999124% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-22-31
# 0.4296361245067952% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-41-49
# 0.4340201665935993% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_14-41-51
# 0.4384042086804033% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-34-11
# 0.4427882507672074% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_18-11-57
# 0.4471722928540114% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-34-56
# 0.45155633494081543% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-50-04
# 0.45594037702761947% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-18-07
# 0.4603244191144235% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-09-21
# 0.4647084612012275% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-25-35
# 0.4690925032880316% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-49-22
# 0.4734765453748356% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-26-29
# 0.4778605874616397% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-19-54
# 0.48224462954844366% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-45-22
# 0.48662867163524776% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-30-46
# 0.49101271372205174% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-19-12
# 0.4953967558088557% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-04-35
# 0.4997807978956598% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-05-31
# 0.5041648399824638% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-37-57
# 0.5085488820692678% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-08-32
# 0.5129329241560718% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-04-14
# 0.5173169662428759% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-27-54
# 0.5217010083296799% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-45-39
# 0.526085050416484% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-14-54
# 0.530469092503288% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-46-30
# 0.5348531345900921% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-13-06
# 0.5392371766768961% complete.
# Transforming image stack Training/Absent/6S_Sat_03-Jun-2019_15-11-25
# 0.5436212187637002% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-06-09
# 0.5480052608505042% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-34-32
# 0.5523893029373083% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-34-08
# 0.5567733450241122% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-20-53
# 0.5611573871109163% complete.
# Transforming image stack Training/Absent/XS_Negative_Random
complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-49-46
# 0.7847435335379219% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-13-46
# 0.789127575624726% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-30-59
# 0.79351161771153% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-50-50
# 0.7978956597983341% complete.
# Transforming image stack Training/Absent/XS_Sat_17-Apr-2019_11-21-34
# 0.8022797018851381% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-36-53
# 0.8066637439719422% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-36-16
# 0.8110477860587462% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-24-52
# 0.8154318281455502% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-53-10
# 0.8198158702323541% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-37-51
# 0.8241999123191581% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-08-25
# 0.8285839544059623% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-59-50
# 0.8329679964927663% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-48-54
# 0.8373520385795703% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-45-29
# 0.8417360806663743% complete.
# Transforming image stack Training/Absent/6_Sat_03-Jun-2019_16-09-05
# 0.8461201227531785% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-37-08
# 0.8505041648399825% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-21-07
# 0.8548882069267865% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-30-18
# 0.8592722490135905% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_13-36-46
# 0.8636562911003947% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-03-52
# 0.8680403331871986% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-19-40
# 0.8724243752740026% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-10-38
# 0.8768084173608066% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-04-46
# 0.8811924594476108% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-27-28
# 0.8855765015344148% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-36-53
# 0.8899605436212188% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-35-57
# 0.8943445857080228% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-48-01
# 0.8987286277948269% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-54-36
# 0.9031126698816309% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-20-16
# 0.907496711968435% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-59-02
# 0.9118807540552389% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-11-44
# 0.9162647961420429% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_13-49-07
# 0.920648838228847% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-08-08
# 0.925032880315651% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-37-08
# 0.929416922402455% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-51-37
# 0.933800964489259% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-48-32
# 0.9381850065760632% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-04-02
# 0.9425690486628672% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-29-19
# 0.9469530907496712% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-09-00
# 0.9513371328364751% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-50-17
# 0.9557211749232793% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-37-02
# 0.9601052170100833% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-03-24
# 0.9644892590968873% complete.
# Transforming image stack Training/Absent/XS_Negative_Random
complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-02-24
# 1.4291977202981148% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-24-18
# 1.4335817623849187% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-18-22
# 1.437965804471723% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_14-42-51
# 1.442349846558527% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-43-24
# 1.446733888645331% complete.
# Transforming image stack Training/Absent/XS_Sat_17-Apr-2019_12-04-06
# 1.451117930732135% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-10-42
# 1.4555019728189391% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-32-22
# 1.459886014905743% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-29-54
# 1.464270056992547% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-22-53
# 1.468654099079351% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-06-07
# 1.4730381411661553% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-20-30
# 1.4774221832529593% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_17-01-25
# 1.4818062253397632% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-16-35
# 1.4861902674265672% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-15-48
# 1.4905743095133712% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-38-01
# 1.4949583516001754% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-33-13
# 1.4993423936869794% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-26-45
# 1.5037264357737834% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_13-42-14
# 1.5081104778605874% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-25-08
# 1.5124945199473916% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-20-16
# 1.5168785620341956% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-56-09
# 1.5212626041209996% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-31-23
# 1.5256466462078035% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-55-26
# 1.5300306882946078% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-06-42
# 1.5344147303814117% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-29-16
# 1.5387987724682157% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-56-27
# 1.5431828145550197% complete.
# Transforming image stack Training/Absent/XS_Sat_30-May-2019_15-50-54
# 1.547566856641824% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-02-33
# 1.551950898728628% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-16-40
# 1.5563349408154319% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-52-08
# 1.5607189829022359% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-50-51
# 1.56510302498904% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-31-35
# 1.5694870670758438% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-20-37
# 1.573871109162648% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-40-56
# 1.578255151249452% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-41-15
# 1.582639193336256% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-38-29
# 1.58702323542306% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-01-29
# 1.591407277509864% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-56-25
# 1.5957913195966682% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-52-01
# 1.6001753616834722% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-35-21
# 1.6045594037702762% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-19-57
# 1.6089434458570802% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-25-27
# 1.6133274879438844% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019
complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-44-40
# 1.8632178868917142% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-13-37
# 1.867601928978518% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_13-13-29
# 1.8719859710653222% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_17-24-42
# 1.8763700131521264% complete.
# Transforming image stack Training/Absent/6S_Sat_16-Apr-2019_15-35-00
# 1.8807540552389301% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-35-47
# 1.8851380973257343% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-05-09
# 1.889522139412538% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-05-02
# 1.8939061814993423% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-41-17
# 1.8982902235861465% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-16-19
# 1.9026742656729503% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_12-47-01
# 1.9070583077597545% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-16-04
# 1.9114423498465587% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-56-44
# 1.9158263919333625% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-30-10
# 1.9202104340201667% complete.
# Transforming image stack Training/Absent/7_Sat_30-May-2019_16-57-46
# 1.9245944761069704% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-02-50
# 1.9289785181937746% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-26-13
# 1.9333625602805788% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-05-56
# 1.9377466023673826% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_16-41-09
# 1.9421306444541868% complete.
# ...
# 16.694432266549757% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-18-56
# 16.698816308636562% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-40-31
# 16.703200350723364% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-36-44
# 16.70758439281017% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-03-27
# 16.711968434896978% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-27-35
# 16.71635247698378% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-39-29
# 16.720736519070584% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-44-02
# 16.725120561157386% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-12-12
# 16.72950460324419% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-31-54
# 16.733888645330996% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-50-49
# 16.738272687417798% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-37-18
# 16.742656729504603% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-20-28
# 16.747040771591408% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-04-57
# 16.751424813678213% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-14-29
# 16.755808855765014% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-40-15
# 16.76019289785182% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-21-56
# 16.764576939938625% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-18-05
# 16.768960982025426% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-04-13
# 16.77334502411223% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-41-50
# 16.777729066199036% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_13-48-03
# 16.78211310828584% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-06-27
# 16.786497150372643% complete.
# Transforming image stack Training/Absent/6S_Negative_Random_03-Jun-2019_14-23-02
# 16.790881192459448% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_16-49-35
# 16.795265234546253% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-45-22
# 16.799649276633055% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-05-11
# 16.80403331871986% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-30-20
# 16.80841736080666% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-11-01
# 16.812801402893466% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_17-02-14
# 16.81718544498027% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-22-44
# 16.821569487067077% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-21-29
# 16.82595352915388% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-08-22
# 16.830337571240683% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-47-34
# 16.83472161332749% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-06-39
# 16.83910565541429% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-39-26
# 16.843489697501095% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_10-53-02
# 16.8478737395879% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-12-06
# 16.852257781674705% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-30-44
# 16.85664182376151% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-09-13
# 16.861025865848312% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-28-24
# 16.865409907935117% complete.
# Transforming image stack Training/Absent/XS_Sat_17-Apr-2019_11-53-34
# 16.86979395002192% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-48-08
# 16.874177992108724% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-37-49
# 16.87856203419553% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-31-24
# 16.88294607628233% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-08-34
# 16.887330118369135% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-31-00
# 16.89171416045594% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-36-32
# 16.896098202542746% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-14-53
# 16.900482244629547% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-18-56
# 16.904866286716352% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_18-03-11
# 16.909250328803157% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_12-25-23
# 16.91363437088996% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-30-07
# 16.918018412976764% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_16-10-28
# 16.92240245506357% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-36-01
# 16.926786497150374% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-12-00
# 16.931170539237176% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-14-06
# 16.93555458132398% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-20-47
# 16.939938623410786% complete.
# Transforming image stack Training/Absent/SE_Negative_Random_03-Jun-2019_16-32-51
# 16.944322665497587% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-43-53
# 16.948706707584392% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_16-49-54
# 16.953090749671198% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-17-34
# 16.957474791758003% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-40-16
# 16.961858833844808% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-47-19
# 16.96624287593161% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_16-03-07
# 16.970626918018414% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_18-27-41
# 16.975010960105216% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-05-40
# 16.97939500219202% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-20-43
# 16.983779044278823% complete.
# Transforming image stack Training/Absent/XS_Sat_07-Jun-2019_14-01-13
# 16.988163086365628% complete.
# Transforming image stack Training/Absent/XS_Negative_Sample3_Light_17-Apr-2019_11-57-28
# 16.992547128452433% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-21-52
# 16.996931170539238% complete.
# Transforming image stack Training/Absent/7_Sat_30-May-2019_16-46-53
# 17.001315212626043% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_14-53-40
# 17.005699254712844% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-31-19
# 17.01008329679965% complete.
# Transforming image stack Training/Absent/6S_Sat_03-Jun-2019_15-34-05
# 17.01446733888645% complete.
# Transforming image stack Training/Absent/6S_Negative_Sample3_Light_16-Apr-2019_15-57-06
# 17.018851380973256% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_20-42-33
# 17.02323542306006% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-38-54
# 17.027619465146866% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-24-59
# 17.03200350723367% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-30-47
# 17.036387549320473% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-39-11
# 17.040771591407278% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-15-34
# 17.045155633494083% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_10-32-31
# 17.049539675580885% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-36-37
# 17.05392371766769% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_18-03-27
# 17.05830775975449% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-35-03
# 17.062691801841297% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_11-01-21
# 17.0670758439281% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_18-27-05
# 17.071459886014907% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_14-27-24
# 17.075843928101712% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_04-Jun-2019_10-45-21
# 17.080227970188513% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_18-59-44
# 17.08461201227532% complete.
# Transforming image stack Training/Absent/6S_Negative_Dark_14-Mar-2019_09-42-54
# 17.08899605436212% complete.
# Transforming image stack Training/Absent/SE_Negative_Dark_15-Mar-2019_15-43-29
# 17.093380096448925% complete.
# Transforming image stack Training/Absent/XS_Negative_Dark_14-Mar-2019_17-33-28
# 17.09776413853573% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_11-41-03
# 17.102148180622535% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_17-16-11
# 17.10653222270934% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-25-16
# 17.110916264796142% complete.
# Transforming image stack Training/Absent/6_Negative_Dark_13-Mar-2019_12-38-10
# 17.115300306882947% complete.
# Transforming image stack Training/Absent/7_Negative_Random_30-May-2019_16-21-33
# 17.11968434896975% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-23-37
# 17.124068391056554% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_17-28-17
# 17.128452433143355% complete.
# Transforming image stack Training/Absent/7_Negative_Dark_13-Mar-2019_18-01-24
# 17.132836475230164% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_15-49-03
# 17.13722051731697% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-26-27
# 17.14160455940377% complete.
# Transforming image stack Training/Absent/6_Negative_Sample3_Back_Light_16-Apr-2019_13-12-42
# 17.145988601490576% complete.
# Transforming image stack Training/Absent/7_Negative_Sample3_Light_16-Apr-2019_17-23-30
# 17.150372643577377% complete.
# Transforming image stack Training/Absent/XS_Negative_Random_30-May-2019_14-31-56
# 17.154756685664182% complete.
# Transforming image stack Training/Absent/XS_Sat2_07-Jun-2019_19-14-49
# 17.159140727750987% complete.
# Transforming image stack Training/Absent/XS_Sat_04-Jun-2019_10-01-22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f0bb9e94c386> in <module>()
# ----> 1 transform_to_pickle(model,topDirName)
#
# <ipython-input-21-bd5882d29799> in transform_to_pickle(model, topdir)
#      42                 imgArr[0][2] = ((imgArr[0][2] - 103.53)/57.375)
#      43                 if torch.cuda.is_available():
# ---> 44                     output.append(model(torch.cuda.FloatTensor(imgArr)))
#      45                 else:
#      46                     output.append(model(torch.FloatTensor(imgArr)))
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torchvision/models/densenet.py in forward(self, x)
#     111
#     112     def forward(self, x):
# --> 113         features = self.features(x)
#     114         out = F.relu(features, inplace=True)
#     115         out = F.adaptive_avg_pool2d(out, (1, 1)).view(features.size(0), -1)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torchvision/models/densenet.py in forward(self, x)
#      31
#      32     def forward(self, x):
# ---> 33         new_features = super(_DenseLayer, self).forward(x)
#      34         if self.drop_rate > 0:
#      35             new_features = F.dropout(new_features, p=self.drop_rate, training=self.training)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/derm-ai/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %% [markdown]
# Clean up the directory, removing everything but the pickle files.

# %%
# Assemble all the pickle files and remove the rest.
classDirs = [direc for direc in os.listdir(topDirName) if direc[0] is not '.']
for classDir in classDirs:
    newDir = os.path.join(topDirName,classDir)
    fileDirs = [direc for direc in os.listdir(newDir) if direc[0] is not '.' and not direc.lower().endswith('.pickle')]
    for fileDir in fileDirs:
        pickleFileDir = os.path.join(newDir,fileDir)
        os.system('rm -rf ' + pickleFileDir)

# %% [markdown]
# # Split the directory into train/test/validation sets

# %%
import random

# %%
finalDirName = 'Split_Data'

# %%
def split_folders(inputDir, outputDir, trainValTestRatio, seed):
    # Assume inputDir is organized as 'inputDir/class/topFolder/photos'
    classes = os.listdir(inputDir)
    # Exclude folders where '.' is the first character.
    classes = [directory for directory in classes if directory[0] != '.']
    numClasses = len(classes)
    # Create output directories
    os.system('mkdir ' + outputDir)
    os.system('mkdir ' + outputDir + '/train')
    os.system('mkdir ' + outputDir + '/valid')
    os.system('mkdir ' + outputDir + '/test')
    # Pull files and put into the appropriate folders.
    for directory in classes:
        files = os.listdir(os.path.join(inputDir, directory))
        files.sort()
        random.seed(seed)
        random.shuffle(files)
        numFiles = len(files)
        # Get the indices.
        ndxAmts = np.intc((np.round(trainValTestRatio / np.sum(trainValTestRatio) * numFiles)))
        numNdxes = np.sum(ndxAmts)
        if numNdxes != numFiles:
            ndxAmts[0] += numFiles-numNdxes
        trainFiles = files[0:ndxAmts[0]]
        valFiles = files[ndxAmts[0]:ndxAmts[0]+ndxAmts[1]]
        testFiles = files[ndxAmts[0]+ndxAmts[1]:]
        # Put the training directories in the appropriate folder
        # First make the class directories.
        os.system('mkdir ' + outputDir + '/train/' + directory)
        os.system('mkdir ' + outputDir + '/valid/' + directory)
        os.system('mkdir ' + outputDir + '/test/' + directory)
        for file in trainFiles:
            os.system('cp -r ' + inputDir + '/' + directory + '/' + file + ' ' + outputDir + '/train/' + directory + '/' + file)
        for file in valFiles:
            os.system('cp -r ' + inputDir + '/' + directory + '/' + file + ' ' + outputDir + '/valid/' + directory + '/' + file)
        for file in testFiles:
            os.system('cp -r ' + inputDir + '/' + directory + '/' + file + ' ' + outputDir + '/test/' + directory + '/' + file)

# %%
split_folders(topDirName, finalDirName,[0.8,0.1,0.1],7778)
